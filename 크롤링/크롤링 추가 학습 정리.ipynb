# %%
<크롤링 복습>
# api 받아올 때도 requests 사용함
# 400번 오류 --> 자바스크립
# 500번 오류 --> 서브릿 , 데이터베이스
# 잡코리아 같은 사이트는 --> 셀레니움 자동차단 
# 딕-->객체=키값 / 리스트-->배열=인덱스값
# csv파일 --> 한글인코딩은 엑셀같은 것으로 실행시 인코딩이 자체적으로 되므로 따로 인코딩 코드 안줘도 됨 
# 예외처리 --> 디비,파일저장,판다스 --> 누락데이터는 반드시 다른 값이나 '없음' 값을 주어야 함
# 프린트에 값을 주는 것은 단지 콘솔창처럼 보이면서 에러발생시 긴 에러표시 뜨는 것 방지용 일뿐 실제로 예외시 값을 어떻게든 주어야 한다
# 반복문은 바로 for 적지 말고 반복로직을 먼저 적고 for문 적고 범위는 리스트의 len값
# 사이트에 팝업창 뜨면 크롤링 안됨 --> 반드시 팝업을 끄거나 팝업창을 끄는 코드를 작성
# 팝업창을 끄는 코드는 try except로~ --> 팝업이 안뜰수도 있으므로~
# 이미지 수집시 원하는 화면이미지가  아래에 있을 시 스크롤를 직접하든가 
# 아니면 스크롤하는 코드삽입해서 해당 이미지로 이동하고 수집해야함..
# 네이버지도화면 --> 원본데이터와 아이프레임 사이를 오가는 로직이므로 반복문 실행시 time.sleep(1)을 많이 줘야함
# 바탕화면 폴더 변경 --> 바탕화면 폴더 우클릭 속성 --> 위치에서 이름을 영문으로 변경가능
# ==================================================================================
<크롤링시험범위>
#** beatifulSoup 사용 목적 --> 필기
#** 멜론챠트 --> 시험
#** find_element와 find_elements의 차이점
#** 한솥도시락--> 더보기 완료 후 실행 ,실기
#** 지마켓 --> 실기
#** 셀레니움 자동화 -->실기
# ==============================================
