# %%
# 그래프 라이브러리
# matplotlib

# %% [markdown]
# # 데이터 시각화

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt

# %%
# 배열 생성하여 데이터 준비
x = np.arange(1,6)
np.random.seed(3) # 랜덤값을 고정
y = np.random.randint(1,10,size=5)
print(x)
print(y)
# Out:
# [1 2 3 4 5]
# [9 4 9 9 1]

# %%
# 선그래프 그리기
# plt.plot(x축데이터,y축데이터)
plt.plot(x,y)

# 주피터 노트북 , 구글colab 환경에서는 plot을 그릴때 별도의 코드 없이 그래프가 출력된다
# vscode, pytorvh 등 plt.show()까지 작성
plt.show()

# %%
# 선 그리는 경우 x축 생략 가능함
plt.plot(y)
plt.show()

# %% [markdown]
# # 선 그래프의 옵션
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 선그래프 스타일 변경
# marker= 포인트에 스타일 변경
# ms= marker 사이즈
# mec = marker edge color = 색깔이니셜사용
# mew = marker edge 선굵기
# mfc = marker 내부색깔

plt.plot(x,y,ls=":",marker='D',ms=10, mec='r', mew = 3, mfc='g')
plt.show()

# %% [markdown]
# ## 하나의 출력문에 여러개 그래프

# %%
plt.plot(x,y, ls = '-',  color='b' ,marker='D', ms=10, mec='c',mew=4, mfc='y')
plt.plot(x,y, ls = '--', color='m', lw=5)
plt.plot(x,y, ls = '-.')
plt.plot(x,y, ls = ':')
plt.show()
# 별도의 코드기 없으면 겹쳐서 출력

# %% [markdown]
# ###  plt.subplot(row,col,index)
# - 행 열 인덱스

# %%
# 하나의 출력문에 여러개 그래프
# plt.subplot()

plt.subplot(3,2,1)  # 3행2열1번인덱스
plt.plot(x,y,ls = '-', color='b' ,marker='D', ms=10, mec='c',mew=4, mfc='y')

plt.subplot(3,2,2)
plt.plot(x,y, ls = '--', color='m', lw=5)

plt.subplot(3,2,3)
plt.plot(x,y, ls = '-.')

plt.subplot(3,2,4)
plt.plot(x,y, ls = ':')

plt.subplot(3,2,5)
plt.plot(x,y, ls = ':')

plt.subplot(3,2,6)
plt.plot(x,y, ls = ':')

plt.show()

# %%
# 배열 생성하여 데이터 준비
test_x = np.arange(1,6)
np.random.seed(4)
test_y = np.random.randint(1,10,size=5)
print(test_x)
print(test_y)
# Out:
# [1 2 3 4 5]
# [8 6 2 9 8]

# %%
plt.plot(test_x,test_y)
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# 그래프 제목 넣기 --> title()함수

plt.title('hello')
plt.plot(test_x,test_y)
plt.show()

# %%
# 격자눈금 -grid()
plt.grid()
plt.title('test')
plt.plot(test_x,test_y)
plt.show()

# %%
# 범례 -legend() 

test_x1 = np.arange(1,6)
np.random.seed(10)
test_y1 = np.random.randint(1,10,size=5)

# 하나의 출력문에 여러개 그래프
plt.plot(test_x,test_y)
plt.plot(test_x1,test_y1)
# 데이터가 다른 plot이 하나의 출력문에 표현시 라인색이 자동 변경됨-->구분하려고 자동으로 변경되는 것 같음

# subplot()을 쓰면 어차피 인덱스로 구분되어 지므로 라인색은 동일함
#plt.subplot(1,2,1)   
#plt.plot(test_x,test_y)
#plt.subplot(1,2,2)
#plt.plot(test_x1,test_y1)

plt.legend() # 라벨을 안주면 표현이 불완전
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# 범례 -legend() ->두 개이상의 그래프 자료를 한 곳에 표현하는 것

test_x1 = np.arange(1,6)
np.random.seed(10)
test_y1 = np.random.randint(1,10,size=5)

# 등장하려면 plt.plot() 구간에 lable를 작성
plt.plot(test_x,test_y,  label = 'test1')
plt.plot(test_x1,test_y1,label = 'test2')

# plt.plot() 다음에 plt.legend() 코드 작성하기 ***
plt.legend() # 등장하려면 plt.plot하는 구간에 lable를 작성

plt.show()

# %%
# 한글로 라벨이나 제목을 넣고자 할 때
# 한글 폰트 깨질 경우
# 내컴의 가장 기본 폰트인 Malgun Gothic로 한글 적용
# Malgun Gothic은 어떤 컴이든 기본적으로 다 있으므로  font.family를 Malgun Gothic으로 하면 한글이 적용됨
# 다른 폰트가 있다면 영문으로 적으면 된다.
plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
# x라벨 ,y라벨 ->각 축의 이름

plt.plot(test_x,test_y,label = 'test1')
plt.plot(test_x1,test_y1,label = 'test2')

plt.xlabel('x축')
plt.ylabel('y축',rotation=0,loc='top') # 기본값=90각도  rotation- > y라벨의 회전
# loc = 은 y라벨 위치 --> top ,bottom ,center
plt.show()

# %%
# xlim , ylim  -> 리미트의 약자 -> 각축의 범위
# xlim(n,n1) --> x축의 범위를 숫자로~

plt.plot(test_x,test_y,label = 'test1')
plt.plot(test_x1,test_y1,label = 'test2')

plt.xlim(0,10)
plt.ylim(0,10)
#plt.show()   #--> 먼저 show()가 출력된다 뒤의 show()는 미 출력

plt.xlim(0,3)
plt.ylim(0,5)
plt.show()

# %%
# plt.figure(figsize =(x,y))  --> 크기 -> 인치단위 

plt.figure(figsize = (10,3)) 

plt.plot(test_x,test_y,label = 'test1')
plt.plot(test_x1,test_y1,label = 'test2')

plt.show()

# %%
# xticks ,yticks  -> 각 축의 눈금의 범위 조정

plt.plot(test_x,test_y,label = 'test1')
plt.plot(test_x1,test_y1,label = 'test2')

# 리스트 혹은 배열을 넣는다
# 리스트 크기가 데이터의 갯수와는 상관이 없다
plt.xticks([1,2,3,4,5,6,7])
plt.yticks([1,3,5,7,9,11,13])

plt.show()

# %% [markdown]
# ### 인구변동 데이터

# %%
data1 = pd.read_csv('data/장래_인구변동_KOSIS.csv', encoding = 'euc-kr')
data1
# Out:
#     인구변동요인별   2020   2030   2040   2050   2060   2070
# 0    인구(천명)  51836  51199  50193  47359  42617  37656
# 1  출생아수(천명)    275    305    286    236    181    196
# 2  사망자수(천명)    308    408    527    680    741    702

# %%
# 자료의 한글이 있어 encoding = 'euc-kr'
# index_col = '컬럼명' 은 해당 컬럼을 인덱스로 사용한다는 의미
data = pd.read_csv('data/장래_인구변동_KOSIS.csv', encoding = 'euc-kr', index_col = '인구변동요인별')
data
# Out:
#            2020   2030   2040   2050   2060   2070
# 인구변동요인별
# 인구(천명)    51836  51199  50193  47359  42617  37656
# 출생아수(천명)    275    305    286    236    181    196
# 사망자수(천명)    308    408    527    680    741    702

# %% [markdown]
# # 출생아수 ,사망자수를 데이터 시각화

# %%
# 연도별 출생아수 데이터 접근
data_y1 =data.iloc[1]  # 시리즈형식 #y축

#  연도별 사망자수 데이터 접근
data_y2 =data.iloc[2]  # =[2,:]   #y축

# %%
# 컬럼명을 x축으로
data_x = data.columns

# %%
# 하나의 출력문에 2개의 그래프 표현
# 자동으로 선색 차별화

plt.plot(data_x, data_y1, marker ='*', ms=10, label='출생아수(천명)')

plt.plot(data_x, data_y2, marker ='o', ms=8,  label='사망자수(천명)')

# title
plt.title('국가통계 요인별 장래인구 동향')

# grid
plt.grid()

#legend - plt구간에 라벨 작성하기
plt.legend()


plt.show()

# %%
plt.plot(data_x, data_y1, marker = "*", ms = 10, label = "출생아수(천명)")

plt.plot(data_x, data_y2, marker = "o", ms = 8, label = "사망자수(천명)")

# title
plt.title('국가통계 요인별 장래 인구 동향')

# grid
plt.grid()

# legend - plot label 작성 해주기!
plt.legend()

# plt.show()

# 이미지 저장 (경로+파일명, dpi=인치당 노트(작성안하면 기본 해상도 높으면 고해상도), bbox_inches=기본값이tight -> 빈칸 최소화)  )
plt.savefig('./kosis 요인별 장래 인구 동향.png', dpi=600, bbox_inches='tight')

# %% [markdown]
# ### 기상청 api 데이터 그래프 작성하기

# %%
# skiprows=데이터에 행열(표)가 아닌 데이터가 있으면 그 부분은 표시하지 말아라
# skiprows = range(0,7) --> csv파일에서 0행~6행까지 열을 스킵하라
tdata = pd.read_csv('data/기상데이터.csv', encoding = 'euc-kr',skiprows = range(0,7))
tdata.head(2)
tdata
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)
# 0     \t2010-01-01  156     -3.6     -9.5      1.9
# 1     \t2010-01-02  156      1.6     -3.9      6.6
# 2     \t2010-01-03  156      0.4     -1.8      3.5
# 3     \t2010-01-04  156      0.5     -1.8      5.7
# 4     \t2010-01-05  156     -3.0     -4.9      0.2
# ...            ...  ...      ...      ...      ...
# 5155  \t2024-02-12  156      5.8     -0.9     13.0
# 5156  \t2024-02-13  156     10.6      3.4     17.6
# 5157  \t2024-02-14  156     13.5     10.6     19.0
# 5158  \t2024-02-15  156      6.4      0.5     12.4
# 5159  \t2024-02-16  156      4.2     -1.3     10.9
#
# [5160 rows x 5 columns]

# %%
tdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5160 entries, 0 to 5159
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   날짜       5160 non-null   object
#  1   지점       5160 non-null   int64
#  2   평균기온(℃)  5160 non-null   float64
#  3   최저기온(℃)  5160 non-null   float64
#  4   최고기온(℃)  5160 non-null   float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 201.7+ KB

# %%
# 최저기온 시각화
# 1.최저기온 데이터 접근
tdata['최저기온(℃)']
# y축으로~
t_y=tdata['최저기온(℃)']

# %%
#마이너스 기호 사용 코드
# axes = 축
plt.rcParams['axes.unicode_minus'] = False

plt.plot(t_y)  # x축 생략
plt.show()

# %%
# 데이터의 정제가 필요하다
# 날짜를-->월일로 담긴 파생변수
# 월일 이라는 파생변수

# 날짜 컬럼의 데이터 \t2010-01-01 에서 str[-5:] 은 01-01 을 추출해서 새로운 컬럼(월일)에 넣겠다
tdata['월일'] = tdata['날짜'].str[-5:]

tdata['년'] = tdata['날짜'].str[-10:-6] 


tdata
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일     년
# 0     \t2010-01-01  156     -3.6     -9.5      1.9  01-01  2010
# 1     \t2010-01-02  156      1.6     -3.9      6.6  01-02  2010
# 2     \t2010-01-03  156      0.4     -1.8      3.5  01-03  2010
# 3     \t2010-01-04  156      0.5     -1.8      5.7  01-04  2010
# 4     \t2010-01-05  156     -3.0     -4.9      0.2  01-05  2010
# ...            ...  ...      ...      ...      ...    ...   ...
# 5155  \t2024-02-12  156      5.8     -0.9     13.0  02-12  2024
# 5156  \t2024-02-13  156     10.6      3.4     17.6  02-13  2024
# 5157  \t2024-02-14  156     13.5     10.6     19.0  02-14  2024
# 5158  \t2024-02-15  156      6.4      0.5     12.4  02-15  2024
# 5159  \t2024-02-16  156      4.2     -1.3     10.9  02-16  2024
#
# [5160 rows x 7 columns]

# %%
t_x = tdata['월일']
plt.plot(t_x,t_y)
plt.show()

# %%
# 본인 생일날짜 평균기온 연도별 그래프 시각화
# 1.본인 생일날짜 블리언 인덱싱
# 데이터 접근부터 항상 먼저한다

tdata.query('월일=="05-28"')
birth_tdata = tdata.query('월일=="05-28"')
birth_tdata
#birth_tdata.shape --> (14,6)
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일     년
# 147   \t2010-05-28  156     17.7     15.8     21.2  05-28  2010
# 512   \t2011-05-28  156     21.4     16.6     28.1  05-28  2011
# 878   \t2012-05-28  156     23.2     16.5     30.2  05-28  2012
# 1243  \t2013-05-28  156     20.3     18.0     23.2  05-28  2013
# 1608  \t2014-05-28  156     22.3     17.7     28.1  05-28  2014
# 1973  \t2015-05-28  156     24.2     18.8     31.7  05-28  2015
# 2339  \t2016-05-28  156     21.5     17.4     26.9  05-28  2016
# 2704  \t2017-05-28  156     22.1     15.0     30.3  05-28  2017
# 3069  \t2018-05-28  156     21.7     18.3     27.3  05-28  2018
# 3434  \t2019-05-28  156     17.3     12.0     23.0  05-28  2019
# 3800  \t2020-05-28  156     18.6     13.1     25.8  05-28  2020
# 4165  \t2021-05-28  156     17.9     12.9     23.6  05-28  2021
# 4530  \t2022-05-28  156     22.3     16.7     29.7  05-28  2022
# 4895  \t2023-05-28  156     22.7     20.2     26.8  05-28  2023

# %%
# 2. x,y축 설정
y= birth_tdata['평균기온(℃)']
x= range(2010,2024)
# x= range(2010,2025)  --> shape가 15 근데 내 생일의 shape는 14행 고로 2024로 해서 shape를 동일하게 해줘야 한다.
# x= np.arange(2010,2024) --> 가능함

plt.plot(x,y ,marker='D' )

plt.xticks([2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023])
#plt.xlim(2008,2024)

plt.show()

# %%
# 2-1. x,y축 설정
y= birth_tdata['평균기온(℃)']
x= birth_tdata['년']
plt.plot(x,y ,marker='D' )

plt.show()

# %% [markdown]
# ### 히스토그램
# - 분석의 분포도 파악이 주목적

# %%
# 데이터의 빈도를 막대 그래프 형태로 표시한 것
# 주사위를 100번 던져서 나오는 수들의 분포를 히스토그램으로 그려보기
np.random.seed(3)
a = np.random.randint(1,7, size = 10)
np.unique(a, return_counts=True) 

# hist(데이터 ,bins=가로의 구간개수)
# 1~6까지 번호의 중복 분포도 이므로 bins = 6이 좋다 어차피 종류는 6가지다
plt.hist(a, bins = 6)
plt.show()

# %%
a
# Out:
# array([3, 1, 2, 4, 1, 1, 1, 6, 6, 4])

# %%
# 2010~2024년 2월 데이터 최고기온을 히스토로 시각화
# 1.데이터 정제
# tdata 월 데이터 파생변수 만들기
tdata['월']=tdata['월일'].str[:2]
tdata
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일     년   월
# 0     \t2010-01-01  156     -3.6     -9.5      1.9  01-01  2010  01
# 1     \t2010-01-02  156      1.6     -3.9      6.6  01-02  2010  01
# 2     \t2010-01-03  156      0.4     -1.8      3.5  01-03  2010  01
# 3     \t2010-01-04  156      0.5     -1.8      5.7  01-04  2010  01
# 4     \t2010-01-05  156     -3.0     -4.9      0.2  01-05  2010  01
# ...            ...  ...      ...      ...      ...    ...   ...  ..
# 5155  \t2024-02-12  156      5.8     -0.9     13.0  02-12  2024  02
# 5156  \t2024-02-13  156     10.6      3.4     17.6  02-13  2024  02
# 5157  \t2024-02-14  156     13.5     10.6     19.0  02-14  2024  02
# 5158  \t2024-02-15  156      6.4      0.5     12.4  02-15  2024  02
# 5159  \t2024-02-16  156      4.2     -1.3     10.9  02-16  2024  02
#
# [5160 rows x 8 columns]

# %%
# 2010~2024년 2월 데이터 최고기온을 히스토로 시각화
# 2. 2010~2024 2월 데이터 접근 --> 조건이므로 블리언

m2_tdata =tdata.query('월 == "02"')
m2_tdata
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일     년   월
# 31    \t2010-02-01  156      3.6      0.5      7.9  02-01  2010  02
# 32    \t2010-02-02  156     -0.6     -3.9      2.8  02-02  2010  02
# 33    \t2010-02-03  156     -3.3     -5.4      0.4  02-03  2010  02
# 34    \t2010-02-04  156     -1.4     -5.8      4.1  02-04  2010  02
# 35    \t2010-02-05  156     -0.7     -4.3      4.4  02-05  2010  02
# ...            ...  ...      ...      ...      ...    ...   ...  ..
# 5155  \t2024-02-12  156      5.8     -0.9     13.0  02-12  2024  02
# 5156  \t2024-02-13  156     10.6      3.4     17.6  02-13  2024  02
# 5157  \t2024-02-14  156     13.5     10.6     19.0  02-14  2024  02
# 5158  \t2024-02-15  156      6.4      0.5     12.4  02-15  2024  02
# 5159  \t2024-02-16  156      4.2     -1.3     10.9  02-16  2024  02
#
# [411 rows x 8 columns]

# %%
# 2010~2024년 2월 데이터 최고기온을 히스토로 시각화
# 3.최고기온만 뽑기

hist_tdata = m2_tdata['최고기온(℃)']

# %%
# 온도가 소수점까지 있으므로 종류가 매우 다양하다  bins = 100~200 정도는 주자
# 세로축은 온도값의 분포도
# 가로축은 온도 범위
plt.hist(hist_tdata, bins = 200)
plt.show()

# %%
# 히스토그램 꾸미기
# color --> 색꾸미기
# alpha --> 투명도값(0~1사이 소수로~1에 가까우면 진함)
# label --> 지정가능
# 히스토도 겹치기 가능 

plt.hist(m2_tdata['최저기온(℃)'],bins = 100,color='b',alpha=0.5,label='최저기온')
plt.hist(hist_tdata, bins = 100,color='r',alpha=0.5,label='최고기온')

plt.title('2월 최고/최저 기온')
plt.grid()
plt.legend()
plt.show()

# %% [markdown]
# ### boxplot
# - box: 데이터의 사분위 범위를 나타내느 것 (2~3 분위의 데이터를 표시)
#
# - 수염의 의미 : 1사분위와 4사분위의 데이터
#
# - 박스안의 주황선 : 중앙값(평균값 아니다)
#
# - 점 의미 : 주로 수염 바깥쪽에 존재 -->이상치
#     - 중앙값,분위별 데이터 확인 이상치 데이터 확인

# %%
list2=[]
for i in range(1,4) :
    for i in range(5,8) :
            list2.append([i,i+1])
list2
# Out:
# [[5, 6], [6, 7], [7, 8], [5, 6], [6, 7], [7, 8], [5, 6], [6, 7], [7, 8]]

# %%
list3=[]
for i in range(1,4) :
    list3.append([i,i+1])
list3
# Out:
# [[1, 2], [2, 3], [3, 4]]

# %%
list4=[]
for i in range(5,8) :
    list4.append([i,i+1])
list4
# Out:
# [[5, 6], [6, 7], [7, 8]]

# %%
list5=[list3,list4]
print(list5)
aaa=np.array(list5)
print(aaa.shape)
print(aaa.ndim)
list5[1][2][0]
# Out:
# [[[1, 2], [2, 3], [3, 4]], [[5, 6], [6, 7], [7, 8]]]
# (2, 3, 2)
# 3
# 7

# %%
list6=[list3]
print(list6)
aa=np.array(list6)
print(aa.shape)
print(aa.ndim)
list6[0][2][0]
# Out:
# [[[1, 2], [2, 3], [3, 4]]]
# (1, 3, 2)
# 3
# 3

# %%
# 1D 데이터 준비하여 박스 플롯 그려보기
np.random.seed(1)
tmp_data = np.random.randint(10,size = 10)
print(tmp_data)
tmp_data= np.append(tmp_data, 20)
print(tmp_data)
plt.boxplot(tmp_data, labels=['데이터명'])
plt.show()
# Out:
# [5 8 9 5 0 0 1 7 6 9]
# [ 5  8  9  5  0  0  1  7  6  9 20]

# %%
# 1D 데이터 준비하여 박스 플롯 그려보기
np.random.seed(1)
tmp_data = np.random.randint(10,size = 10)
print(tmp_data)
# tmp_data= np.append(tmp_data, 20)
# print(tmp_data)
plt.boxplot(tmp_data, labels=['데이터명'])
plt.show()
# Out:
# [5 8 9 5 0 0 1 7 6 9]

# %%
tmp_data
# Out:
# array([5, 8, 9, 5, 0, 0, 1, 7, 6, 9])

# %%
m2_tdata['평균기온(℃)']
# Out:
# 31       3.6
# 32      -0.6
# 33      -3.3
# 34      -1.4
# 35      -0.7
#         ...
# 5155     5.8
# 5156    10.6
# 5157    13.5
# 5158     6.4
# 5159     4.2
# Name: 평균기온(℃), Length: 411, dtype: float64

# %%
# plt.boxplot(데이터,labels=['데이터명'])

# %%
plt.boxplot(m2_tdata['평균기온(℃)'],labels=['평균기온'])
plt.show()

# %%
m2_tdata[m2_tdata['평균기온(℃)']<-5]
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일     년   월
# 762   \t2012-02-02  156     -7.9     -9.7     -5.2  02-02  2012  02
# 768   \t2012-02-08  156     -5.7     -9.3     -2.0  02-08  2012  02
# 1134  \t2013-02-08  156     -6.3     -9.7     -1.4  02-08  2013  02
# 2956  \t2018-02-04  156     -5.9     -8.3     -3.0  02-04  2018  02
# 2957  \t2018-02-05  156     -5.6     -8.5     -1.7  02-05  2018  02
# 2958  \t2018-02-06  156     -6.5     -9.8     -2.8  02-06  2018  02

# %%
m2_tdata[m2_tdata['평균기온(℃)']>14]
# Out:
#                 날짜   지점  평균기온(℃)  최저기온(℃)  최고기온(℃)     월일     년   월
# 54    \t2010-02-24  156     14.5      5.9     20.6  02-24  2010  02
# 55    \t2010-02-25  156     15.9     14.5     18.6  02-25  2010  02
# 2234  \t2016-02-13  156     14.2      6.5     19.8  02-13  2016  02

# %% [markdown]
# ### barplot

# %%
# 데이터 준비하여 막대 그래프 그려보기
np.random.seed(6)
bar_x = np.arange(1,4)
bar_y = np.random.randint(50,100,size=3)
print(bar_y)
# plt.bar(x축,y축)
plt.bar(bar_x,bar_y)
plt.show()
# Out:
# [60 59 85]

# %%
# https://matplotlib.org/stable/gallery/color/named_colors.html#base-colors  doc제공 코드
import math
from matplotlib.patches import Rectangle
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors


def plot_colortable(colors, *, ncols=4, sort_colors=True):

    cell_width = 212
    cell_height = 22
    swatch_width = 48
    margin = 12

    # Sort colors by hue, saturation, value and name.
    if sort_colors is True:
        names = sorted(
            colors, key=lambda c: tuple(mcolors.rgb_to_hsv(mcolors.to_rgb(c))))
    else:
        names = list(colors)

    n = len(names)
    nrows = math.ceil(n / ncols)

    width = cell_width * 4 + 2 * margin
    height = cell_height * nrows + 2 * margin
    dpi = 72

    fig, ax = plt.subplots(figsize=(width / dpi, height / dpi), dpi=dpi)
    fig.subplots_adjust(margin/width, margin/height,
                        (width-margin)/width, (height-margin)/height)
    ax.set_xlim(0, cell_width * 4)
    ax.set_ylim(cell_height * (nrows-0.5), -cell_height/2.)
    ax.yaxis.set_visible(False)
    ax.xaxis.set_visible(False)
    ax.set_axis_off()

    for i, name in enumerate(names):
        row = i % nrows
        col = i // nrows
        y = row * cell_height

        swatch_start_x = cell_width * col
        text_pos_x = cell_width * col + swatch_width + 7

        ax.text(text_pos_x, y, name, fontsize=14,
                horizontalalignment='left',
                verticalalignment='center')

        ax.add_patch(
            Rectangle(xy=(swatch_start_x, y-9), width=swatch_width,
                      height=18, facecolor=colors[name], edgecolor='0.7')
        )

    return fig

# %%
plot_colortable(mcolors.CSS4_COLORS)
plt.show()

# %%
# barplot 꾸미기
# 색지정
plt.bar(bar_x,bar_y ,color='g')
plt.show()

# %%
# 색지정을 바별로 적용
# color=[]
plt.bar(bar_x,bar_y ,color=['limegreen','mediumslateblue','orange'])
plt.show()

# %%
bar_x
# Out:
# array([1, 2, 3])

# %%
bar_y
# Out:
# array([60, 59, 85])

# %%
# bar위에 데이터값 작성 --> 텍스트설정하기
# 매개변수 4개
# plt.text(x,y 축값,'string',fontdict={'color': ' ' , 'size' : 00 })

plt.bar(bar_x,bar_y ,color=['limegreen','mediumslateblue','orange'])

#plt.text(1,60, '60' ,fontdict={'color':'black' , 'size' :15})
#plt.text(2,59, '59' ,fontdict={'color':'black' , 'size' :15})
#plt.text(3,85, '85' ,fontdict={'color':'black' , 'size' :15})

# text(ha= va=)
# ha=호리젠탈 va=버티컬얼라이먼트
# ha=센터 왼 오른
# va=탑,바텀,센터,베이스라인,센터베이스라인
# 텍스트가 기준으로 수직선 수평선을 방향이동 --> 헷갈린다


for i in range(len(bar_x)):  # 0,1,2
    plt.text(bar_x[i],bar_y[i], bar_y[i] ,fontdict={'color':'black' , 'size' :15},ha='center',va='top')

plt.show()

# %%
economic = pd.read_csv('data/시도_성별_경제활동인구_총괄_KOSIS_2022.csv', encoding = 'euc-kr')
economic.head()
economic
# Out:
#    행정구역(시도)  성별  15세이상인구 (천명)  경제활동인구 (천명)  취업자 (천명)  실업자 (천명)  비경제활동인구 (천명)  \
# 0     서울특별시  남자          4007         2849      2760        89          1158
# 1     서울특별시  여자          4440         2418      2347        72          2022
# 2     부산광역시  남자          1406          973       946        27           433
# 3     부산광역시  여자          1528          768       745        23           760
# 4     대구광역시  남자          1001          708       691        17           294
# 5     대구광역시  여자          1071          556       543        13           515
# 6     인천광역시  남자          1279          955       928        27           324
# 7     인천광역시  여자          1309          732       717        15           577
# 8     광주광역시  남자           623          434       423        10           190
# 9     광주광역시  여자           656          346       339         8           309
# 10    대전광역시  남자           635          466       461         5           169
# 11    대전광역시  여자           653          353       346         7           300
# 12    울산광역시  남자           489          360       349        11           129
# 13    울산광역시  여자           466          230       224         6           236
# 14  세종특별자치시  남자           156          120       119         2            36
# 15  세종특별자치시  여자           158           85        83         1            74
# 16      경기도  남자          5944         4560      4459       101          1384
# 17      경기도  여자          5981         3283      3199        84          2697
# 18      강원도  남자           651          465       454        11           186
# 19      강원도  여자           675          403       393        10           272
# 20     충청북도  남자           722          555       543        12           167
# 21     충청북도  여자           708          402       399         3           306
# 22     충청남도  남자           975          754       740        14           221
# 23     충청남도  여자           938          550       542         8           388
# 24     전라북도  남자           766          548       540         9           218
# 25     전라북도  여자           790          453       446         7           337
# 26     전라남도  남자           762          580       571         8           182
# 27     전라남도  여자           763          460       454         6           302
# 28     경상북도  남자          1166          875       854        21           290
# 29     경상북도  여자          1161          652       638        14           509
# 30     경상남도  남자          1427         1036      1009        27           391
# 31     경상남도  여자          1421          760       740        20           661
# 32  제주특별자치도  남자           285          227       221         5            59
# 33  제주특별자치도  여자           291          197       195         2            94
#
#     경제활동참가율(％)  고용률(%)  실업률(%)
# 0         71.1    68.9     3.1
# 1         54.5     NaN     3.0
# 2         69.2    67.3     2.7
# 3         50.3    48.8     3.0
# 4         70.6    69.0     2.3
# 5         51.9     NaN     NaN
# 6         74.7     NaN     NaN
# 7         55.9     NaN     2.0
# 8         69.6     NaN     2.4
# 9         52.8     NaN     2.3
# 10        73.4     NaN     1.0
# 11        54.0     NaN     2.0
# 12        73.7    71.3     3.2
# 13        49.4    48.2     2.4
# 14        77.0    75.9     1.4
# 15        53.4    52.5     1.7
# 16        76.7    75.0     2.2
# 17        54.9     NaN     2.6
# 18        71.4    69.7     2.3
# 19        59.7    58.2     2.5
# 20        76.9    75.2     2.2
# 21        56.7    56.4     0.6
# 22        77.3    76.0     NaN
# 23        58.6    57.8     NaN
# 24        71.5    70.4     NaN
# 25        57.3    56.4     1.5
# 26        76.1    75.0     1.4
# 27        60.4     NaN     1.3
# 28        75.1    73.3     2.4
# 29        56.2    55.0     2.1
# 30        72.6    70.7     2.6
# 31        53.5    52.0     NaN
# 32        79.4    77.6     2.3
# 33        67.6    66.9     1.0

# %%
#고용률(%) , 실업률(%)이 이상하다
economic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   행정구역(시도)      34 non-null     object
#  1   성별            34 non-null     object
#  2   15세이상인구 (천명)  34 non-null     int64
#  3   경제활동인구 (천명)   34 non-null     int64
#  4   취업자 (천명)      34 non-null     int64
#  5   실업자 (천명)      34 non-null     int64
#  6   비경제활동인구 (천명)  34 non-null     int64
#  7   경제활동참가율(％)    34 non-null     float64
#  8   고용률(%)        24 non-null     float64
#  9   실업률(%)        28 non-null     float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 2.8+ KB

# %%
economic['고용률(%)']


# 고용률 공식 = 취업자/15세이상 인구
# 넌값을 채우자
# 구한 값이 유사한지 보자 --> 같다
economic['고용률(%)']=economic['취업자 (천명)']/economic['15세이상인구 (천명)']*100
# 컬럼명은 그대로 하고 값을 채움
economic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   행정구역(시도)      34 non-null     object
#  1   성별            34 non-null     object
#  2   15세이상인구 (천명)  34 non-null     int64
#  3   경제활동인구 (천명)   34 non-null     int64
#  4   취업자 (천명)      34 non-null     int64
#  5   실업자 (천명)      34 non-null     int64
#  6   비경제활동인구 (천명)  34 non-null     int64
#  7   경제활동참가율(％)    34 non-null     float64
#  8   고용률(%)        34 non-null     float64
#  9   실업률(%)        28 non-null     float64
# dtypes: float64(3), int64(5), object(2)
# memory usage: 2.8+ KB

# %%
economic['실업률(%)']
# Out:
# 0     3.1
# 1     3.0
# 2     2.7
# 3     3.0
# 4     2.3
# 5     NaN
# 6     NaN
# 7     2.0
# 8     2.4
# 9     2.3
# 10    1.0
# 11    2.0
# 12    3.2
# 13    2.4
# 14    1.4
# 15    1.7
# 16    2.2
# 17    2.6
# 18    2.3
# 19    2.5
# 20    2.2
# 21    0.6
# 22    NaN
# 23    NaN
# 24    NaN
# 25    1.5
# 26    1.4
# 27    1.3
# 28    2.4
# 29    2.1
# 30    2.6
# 31    NaN
# 32    2.3
# 33    1.0
# Name: 실업률(%), dtype: float64

# %%
economic[['행정구역(시도)','고용률(%)']]
# Out:
#    행정구역(시도)     고용률(%)
# 0     서울특별시  68.879461
# 1     서울특별시  52.860360
# 2     부산광역시  67.283073
# 3     부산광역시  48.756545
# 4     대구광역시  69.030969
# 5     대구광역시  50.700280
# 6     인천광역시  72.556685
# 7     인천광역시  54.774637
# 8     광주광역시  67.897271
# 9     광주광역시  51.676829
# 10    대전광역시  72.598425
# 11    대전광역시  52.986217
# 12    울산광역시  71.370143
# 13    울산광역시  48.068670
# 14  세종특별자치시  76.282051
# 15  세종특별자치시  52.531646
# 16      경기도  75.016824
# 17      경기도  53.486039
# 18      강원도  69.738863
# 19      강원도  58.222222
# 20     충청북도  75.207756
# 21     충청북도  56.355932
# 22     충청남도  75.897436
# 23     충청남도  57.782516
# 24     전라북도  70.496084
# 25     전라북도  56.455696
# 26     전라남도  74.934383
# 27     전라남도  59.501966
# 28     경상북도  73.241852
# 29     경상북도  54.952627
# 30     경상남도  70.707779
# 31     경상남도  52.076003
# 32  제주특별자치도  77.543860
# 33  제주특별자치도  67.010309

# %%
# economic 전체가 아니고 economic[['행정구역(시도)','고용률(%)']]에서 그룹바이
# economic 전체 대상으로 행정구역별로 평균을 구하면 문자데이터가 있으므로 .mean(True) 를 해야한다
# economic[['행정구역(시도)','고용률(%)']]을 대상으로 행정구역 별로 평균을 구하니 문자데이터가 없으므로 그냥 .mean()을 한다.
# as_index = False는 그룹바이 한 컬럼을 인덱스로 쓰지 않겠다 --> 인덱스 번호가 자동 생성
# 그룹바이 기본값이 as_index = True 즉 그룹바이 주체가 되는 컬럼이 인덱스가 된다

state_emp = economic[['행정구역(시도)','고용률(%)']].groupby('행정구역(시도)').mean()
state_emp = economic[['행정구역(시도)','고용률(%)']].groupby('행정구역(시도)',as_index = False).mean()
state_emp
#state_emp.head()
# Out:
#    행정구역(시도)     고용률(%)
# 0       강원도  63.980543
# 1       경기도  64.251431
# 2      경상남도  61.391891
# 3      경상북도  64.097240
# 4     광주광역시  59.787050
# 5     대구광역시  59.865625
# 6     대전광역시  62.792321
# 7     부산광역시  58.019809
# 8     서울특별시  60.869911
# 9   세종특별자치시  64.406848
# 10    울산광역시  59.719406
# 11    인천광역시  63.665661
# 12     전라남도  67.218175
# 13     전라북도  63.475890
# 14  제주특별자치도  72.277084
# 15     충청남도  66.839976
# 16     충청북도  65.781844

# %%
# 5) 시도별 고용률 평균 막대 그래프로 시각화하고 고용률이 가장 높은 지역 확인
# Vertical Bar (수직 막대그래프)

plt.figure(figsize =(8,4))

plt.bar(state_emp['행정구역(시도)'], state_emp['고용률(%)'])

plt.xticks(rotation = 45)

plt.title('시도별 고용률 평균 시각화')

plt.xlabel('행정구역(시도)')

plt.ylabel('고용률(%)',rotation = 0 ,loc= 'top')

# ylim 크기 55~80 조절해서 확인
plt.ylim(55,80)

plt.show()
